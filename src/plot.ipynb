# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob

lines = []

path = '../outputs/perplexity/wiki/output_perplexity_nuclear_nd_P28_2.txt'
path = '../outputs/perplexity/wiki/output_perplexity_cyber_2_P2_3.txt'
path = '../outputs/perplexity/wiki/output_perplexity_cyber_nd_P9_0.txt'
# path = '../outputs/perplexity/wiki/output_perplexity_cyber_nd_P19_0.txt'

tokens = []
perplexities = []
with open(path, "r", encoding="utf-8") as file:
    b = False

    prompt = file.readline().split(": ")[1]

    for line in file:
        if "sequence of low perplexity" in line or "Generated" in line:
            break
        if len(line) > 4:
            lines.append(line)
        if b and ":" in line:
            print(line)
            tmp = line.split(": ")
            if len(tmp) > 3:
                token = tmp[1]
                perp_prob = tmp[2]
            else:
                token, perp_prob, _ = tmp 
            perp = perp_prob.split('(')[0]
            tokens.append(token.strip())
            perplexities.append(float(perp))

        if "perplexities:" in line:
            b = True
# Out:
#  It         : 0.7494 (Probability: 0.4726)
#
#  was        : 0.4021 (Probability: 0.6689)
#
#  first      : 2.2283 (Probability: 0.1077)
#
#  published  : 0.0000 (Probability: 1.0000)
#
#  by         : 1.1027 (Probability: 0.3320)
#
#  IBM        : 0.7722 (Probability: 0.4620)
#
#  in         : 0.0000 (Probability: 1.0000)
#
#  1977       : 0.0956 (Probability: 0.9089)
#
#  and        : 1.0930 (Probability: 0.3352)
#
#  was        : 1.2533 (Probability: 0.2856)
#
#  developed  : 2.3609 (Probability: 0.0943)
#
#  by         : 0.3882 (Probability: 0.6783)
#
#  the        : 0.3039 (Probability: 0.7379)
#
#  National   : 0.9925 (Probability: 0.3707)
#
#  Bureau     : 0.0000 (Probability: 1.0000)
#
#  of         : 0.0000 (Probability: 1.0000)
#
#  Standards  : 0.0000 (Probability: 1.0000)
#
#  (          : 0.2033 (Probability: 0.8161)
#
# N           : 0.4093 (Probability: 0.6641)
#
# BS          : 0.0000 (Probability: 1.0000)
#
# ).          : 1.4775 (Probability: 0.2282)
#
# ...

# %%
from IPython.display import HTML, display
from perplexity_plot import visualize_token_perplexity_html

html_code = visualize_token_perplexity_html(tokens, perplexities)
display(HTML(html_code))
# Out:
# <style>
#     .token-perplexity-visualization-block {
#         padding: 15px;
#         border: 1px solid #e0e0e0;
#         border-radius: 8px;
#         background-color: #fdfdfd;
#         margin-bottom: 20px;
#     }
#     .token-perplexity-visualization-block h2 {
#         font-family: Arial, sans-serif;
#         color: #333;
#         margin-top: 0;
#         margin-bottom: 10px;
#         font-size: 1.4em;
#     }
#     .token-perplexity-visualization-block h3.prompt-title {
#         font-family: Arial, sans-serif;
#         color: #555;
#         margin-top: 0;
#         margin-bottom: 8px;
#         font-size: 1.1em;
#         font-weight: normal;
#     }
#     .tokens-container {
#         font-family: Menlo, Monaco, Consolas, "Courier New", monospace;
#         font-size: 16px;
#         line-height: 32.0px;
#         text-align: left; /* Or 'justify' if preferred */
#         word-wrap: break-word; /* Ensure long tokens without spaces can wrap */
#     }
# ...
